# %%
import mdtraj as md
import pyemma
from pyemma.coordinates import source
from pyemma.util.contexts import settings

import MDAnalysis as mda
import matplotlib as mpl
import matplotlib.pyplot as plt
import mdtraj as md
import pyemma
from pyemma.coordinates import source
from pyemma.util.contexts import settings

# %%
import numpy as np

# %%
arr1 = [pyemma.coordinates.load(f'../features_v1/contacts_v1_{i:03d}.npy') for i in range(9)]

# %%
arr2 = [pyemma.coordinates.load(f'../features_v1/coord_v1_{i:03d}.npy') for i in range(9)]

# %%
arr3 = [pyemma.coordinates.load(f'../features_v1/t_new_{i:03d}.npy') for i in range(9)]

# %%
arr4 = [pyemma.coordinates.load(f'../features_v1/ca_com_v1_{i:03d}.npy') for i in range(9)]

# %%
arr5 = [pyemma.coordinates.load(f'../features_v1/torsions_v1_{i:03d}.npy') for i in range(9)]

# %%
arr6 = [pyemma.coordinates.load(f'../features_v1/ca_v1_{i:03d}.npy') for i in range(9)]

# %%
combo_all = [np.concatenate([a1, a2, a3, a4, a5, a6], axis=1) for a1, a2, a3, a4, a5, a6 in zip(arr3, arr4, arr2, arr1, arr5, arr6)]

# %%
combo_ext = [np.concatenate([a1, a2, a3, a4], axis=1) for a1, a2, a3, a4 in zip(arr3, arr4, arr2, arr1)]

# %% [markdown]
# Now we have to start loading these into tICA

# %%
labels = ['contacts','coordination','heavy dists','ca COM dists','torsions','ca-ca','combo-all','comba-ext']

# %%
def score_cv(data, dim, lag, number_of_splits=10, validation_fraction=0.5):
    """Compute a cross-validated VAMP2 score.

    We randomly split the list of independent trajectories into
    a training and a validation set, compute the VAMP2 score,
    and repeat this process several times.

    Parameters
    ----------
    data : list of numpy.ndarrays
        The input data.
    dim : int
        Number of processes to score; equivalent to the dimension
        after projecting the data with VAMP2.
    lag : int
        Lag time for the VAMP2 scoring.
    number_of_splits : int, optional, default=10
        How often do we repeat the splitting and score calculation.
    validation_fraction : int, optional, default=0.5
        Fraction of trajectories which should go into the validation
        set during a split.
    """
    # we temporarily suppress very short-lived progress bars
    with pyemma.util.contexts.settings(show_progress_bars=False):
        nval = int(len(data) * validation_fraction)
        scores = np.zeros(number_of_splits)
        for n in range(number_of_splits):
            ival = np.random.choice(len(data), size=nval, replace=False)
            vamp = pyemma.coordinates.vamp(
                [d for i, d in enumerate(data) if i not in ival], lag=lag, dim=dim)
            scores[n] = vamp.score([d for i, d in enumerate(data) if i in ival])
    return scores


dim = 10

fig, axes = plt.subplots(1, 3, figsize=(12, 3), sharey=True)
for ax, lag in zip(axes.flat, [5, 10, 20]):
    torsions_scores = score_cv(arr1, lag=lag, dim=dim)
    scores = [torsions_scores.mean()]
    errors = [torsions_scores.std()]
    print(scores)
    positions_scores = score_cv(arr2, lag=lag, dim=dim)
    scores += [positions_scores.mean()]
    errors += [positions_scores.std()]
    distances_scores = score_cv(arr3, lag=lag, dim=dim)
    scores += [distances_scores.mean()]
    errors += [distances_scores.std()]
    ca_com_scores = score_cv(arr4, lag=lag, dim=dim)
    scores += [ca_com_scores.mean()]
    errors += [ca_com_scores.std()]
    torsion_scores = score_cv(arr5, lag=lag, dim=dim)
    scores += [torsion_scores.mean()]
    errors += [torsion_scores.std()]
    ca_dist_scores = score_cv(arr6, lag=lag, dim=dim)
    scores += [ca_dist_scores.mean()]
    errors += [ca_dist_scores.std()]
    combo_all_scores = score_cv(combo_all, lag=lag, dim=dim)
    scores += [combo_all_scores.mean()]
    errors += [combo_all_scores.std()]
    combo_ext_scores = score_cv(combo_ext, lag=lag, dim=dim)
    scores += [combo_ext_scores.mean()]
    errors += [combo_ext_scores.std()]
    ax.bar(labels, scores, yerr=errors, color=['C0', 'C1', 'C2','C3','C4','C5','C6','C7'])
    ax.set_title(r'lag time $\tau$={:.1f}ns'.format(lag * 0.1))
    if lag == 5:
        # save for later
        vamp_bars_plot = dict(
            labels=labels, scores=scores, errors=errors, dim=dim, lag=lag)
axes[0].set_ylabel('VAMP2 score')
fig.tight_layout()
# Out:
# [5.525439754556248]
# [4.812801943923747]
# [4.244289832918599]

# %%
lags = [1, 2, 5, 10, 20]
dims = [i + 1 for i in range(20)]

fig, ax = plt.subplots()
for i, lag in enumerate(lags):
    scores_ = np.array([score_cv(arr5, dim, lag)
                        for dim in dims])
    scores = np.mean(scores_, axis=1)
    errors = np.std(scores_, axis=1, ddof=1)
    color = 'C{}'.format(i)
    ax.fill_between(dims, scores - errors, scores + errors, alpha=0.3, facecolor=color)
    ax.plot(dims, scores, '--o', color=color, label='lag={:.1f}ns'.format(lag * 0.1))
ax.legend()
ax.set_xlabel('number of dimensions')
ax.set_ylabel('VAMP2 score')
fig.tight_layout()
# Out:
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:242: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   or len(trajfiles) is 0)):
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:384: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   and (any(isinstance(item, (list, tuple, _string_types)) for item in inp) or len(inp) is 0)):
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:388: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   and (any(isinstance(item, _np.ndarray) for item in inp) or len(inp) is 0)):
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:242: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   or len(trajfiles) is 0)):
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:384: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   and (any(isinstance(item, (list, tuple, _string_types)) for item in inp) or len(inp) is 0)):
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:388: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   and (any(isinstance(item, _np.ndarray) for item in inp) or len(inp) is 0)):
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/estimation/covariance.py:110: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/estimation/covariance.py:111: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/estimation/covariance.py:110: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/estimation/covariance.py:111: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/running_moments.py:208: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/running_moments.py:209: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/running_moments.py:208: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/running_moments.py:209: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:657: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:658: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:777: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:778: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:900: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:901: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:657: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:658: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:777: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:778: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:900: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:901: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:657: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:658: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:777: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:778: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:900: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:901: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:657: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:658: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:777: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:778: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:900: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:901: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:657: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:658: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:777: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:778: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:900: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:901: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:657: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:658: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:777: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:778: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:900: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if diag_only and sparse_mode is not 'dense':
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:901: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if sparse_mode is 'sparse':
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 6
#       4 fig, ax = plt.subplots()
#       5 for i, lag in enumerate(lags):
# ----> 6     scores_ = np.array([score_cv(arr5, dim, lag)
#       7                         for dim in dims])
#       8     scores = np.mean(scores_, axis=1)
#       9     errors = np.std(scores_, axis=1, ddof=1)
#
# Cell In[35], line 6, in <listcomp>(.0)
#       4 fig, ax = plt.subplots()
#       5 for i, lag in enumerate(lags):
# ----> 6     scores_ = np.array([score_cv(arr5, dim, lag)
#       7                         for dim in dims])
#       8     scores = np.mean(scores_, axis=1)
#       9     errors = np.std(scores_, axis=1, ddof=1)
#
# Cell In[33], line 29, in score_cv(data, dim, lag, number_of_splits, validation_fraction)
#      27     for n in range(number_of_splits):
#      28         ival = np.random.choice(len(data), size=nval, replace=False)
# ---> 29         vamp = pyemma.coordinates.vamp(
#      30             [d for i, d in enumerate(data) if i not in ival], lag=lag, dim=dim)
#      31         scores[n] = vamp.score([d for i, d in enumerate(data) if i in ival])
#      32 return scores
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:1422, in vamp(data, lag, dim, scaling, right, ncov_max, stride, skip, chunksize)
#    1420 res = VAMP(lag, dim=dim, scaling=scaling, right=right, skip=skip, ncov_max=ncov_max)
#    1421 if data is not None:
# -> 1422     res.estimate(data, stride=stride, chunksize=chunksize)
#    1423 else:
#    1424     res.chunksize = chunksize
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/data/_base/transformer.py:215, in StreamingEstimationTransformer.estimate(self, X, **kwargs)
#     214 def estimate(self, X, **kwargs):
# --> 215     super(StreamingEstimationTransformer, self).estimate(X, **kwargs)
#     216     # we perform the mapping to memory exactly here, because a StreamingEstimator on its own
#     217     # has not output to be mapped. Only the combination of Estimation/Transforming has this feature.
#     218     if self.in_memory and not self._mapping_to_mem_active:
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/data/_base/streaming_estimator.py:44, in StreamingEstimator.estimate(self, X, chunksize, **kwargs)
#      42 # run estimation
#      43 try:
# ---> 44     super(StreamingEstimator, self).estimate(X, **kwargs)
#      45 except NotConvergedWarning as ncw:
#      46     self.logger.info(
#      47         "Presumably finished estimation. Message: %s" % ncw)
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_base/estimator.py:407, in Estimator.estimate(self, X, **params)
#     405 if params:
#     406     self.set_params(**params)
# --> 407 self._model = self._estimate(X)
#     408 # ensure _estimate returned something
#     409 assert self._model is not None
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/transform/vamp.py:611, in VAMP._estimate(self, iterable, **kw)
#     607 if self._logger_is_active(self._loglevel_DEBUG):
#     608     self.logger.debug("Running VAMP with tau=%i; Estimating two covariance matrices"
#     609                       " with dimension (%i, %i)" % (self._lag, indim, indim))
# --> 611 covar.estimate(iterable, **kw)
#     612 self.model.update_model_params(mean_0=covar.mean,
#     613                                mean_t=covar.mean_tau,
#     614                                C00=covar.C00_,
#     615                                C0t=covar.C0t_,
#     616                                Ctt=covar.Ctt_)
#     617 self.model._diagonalize()
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/data/_base/streaming_estimator.py:44, in StreamingEstimator.estimate(self, X, chunksize, **kwargs)
#      42 # run estimation
#      43 try:
# ---> 44     super(StreamingEstimator, self).estimate(X, **kwargs)
#      45 except NotConvergedWarning as ncw:
#      46     self.logger.info(
#      47         "Presumably finished estimation. Message: %s" % ncw)
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_base/estimator.py:407, in Estimator.estimate(self, X, **params)
#     405 if params:
#     406     self.set_params(**params)
# --> 407 self._model = self._estimate(X)
#     408 # ensure _estimate returned something
#     409 assert self._model is not None
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/estimation/covariance.py:234, in LaggedCovariance._estimate(self, iterable, partial_fit)
#     231         Y = Y - self.remove_constant_mean[np.newaxis, :]
#     233 try:
# --> 234     self._rc.add(X, Y, weights=weight)
#     235 except MemoryError:
#     236     raise MemoryError('Covariance matrix does not fit into memory. '
#     237                       'Input is too high-dimensional ({} dimensions). '.format(X.shape[1]))
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/running_moments.py:294, in RunningCovar.add(self, X, Y, weights)
#     292 assert Y is not None
#     293 assert not self.symmetrize
# --> 294 w, s, C = moments_block(X, Y, remove_mean=self.remove_mean,
#     295                         sparse_mode=self.sparse_mode, modify_data=self.modify_data,
#     296                         column_selection=self.column_selection, diag_only=self.diag_only)
#     297 # make copy in order to get independently mergeable moments
#     298 if self.column_selection is not None:
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:965, in moments_block(X, Y, remove_mean, modify_data, sparse_mode, sparse_tol, column_selection, diag_only)
#     961 else:
#     962     Cxx = _M2(X0, X0, mask_X=mask_X, mask_Y=mask_X,
#     963               xsum=sx_centered, xconst=xconst, ysum=sx_centered, yconst=xconst,
#     964               diag_only=diag_only)
# --> 965     Cxy = _M2(X0, Y0, mask_X=mask_X, mask_Y=mask_Y,
#     966               xsum=sx_centered, xconst=xconst, ysum=sy_centered, yconst=yconst,
#     967               diag_only=diag_only)
#     968     Cyx = Cxy.T
#     969     Cyy = _M2(Y0, Y0, mask_X=mask_Y, mask_Y=mask_Y,
#     970               xsum=sy_centered, xconst=yconst, ysum=sy_centered, yconst=yconst,
#     971               diag_only=diag_only)
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:530, in _M2(Xvar, Yvar, mask_X, mask_Y, xsum, xconst, ysum, yconst, weights, diag_only)
#     528 """ direct (nonsymmetric) second moment matrix. Decide if we need dense, sparse, const"""
#     529 if mask_X is None and mask_Y is None:
# --> 530     return _M2_dense(Xvar, Yvar, weights=weights, diag_only=diag_only)
#     531 else:
#     532     # Check if one of the masks is not None, modify it and also adjust the constant columns:
#     533     if mask_X is None:
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_ext/variational/estimators/moments.py:401, in _M2_dense(X, Y, weights, diag_only)
#     399     return np.sum(X * Y, axis=0)
#     400 else:
# --> 401     return np.dot(X.T, Y)
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
tica_dev = pyemma.coordinates.tica(result, lag=20,dim=2)
tica_out = tica_dev.get_output()
tica_concatenated = np.concatenate(tica_out)
# Out:
# calculate covariances:   0%|                              | 0/9 [00:00<?, ?it/s]
# getting output of TICA:   0%|                             | 0/9 [00:00<?, ?it/s]

# %%
np.shape(combo_ext[0])
# Out:
# (10001, 287)

# %%
np.shape(tica_concatenated)
# Out:
# (98374, 42)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
pyemma.plots.plot_feature_histograms(
    tica_concatenated,
    ax=axes[0],
#     feature_labels=['IC1', 'IC2', 'IC3'],
    ylog=True, ignore_dim_warning=True)
pyemma.plots.plot_density(*tica_concatenated[:, :2].T, ax=axes[1], logscale=True)
axes[1].set_xlabel('IC 1')
axes[1].set_ylabel('IC 2')
fig.tight_layout()
# plt.savefig('tica_update.png', dpi= 300)

# %%
fig, axes = plt.subplots(6, 1, figsize=(12, 5), sharex=True)
x = 0.1 * np.arange(tica_out[0].shape[0])
for i, (ax, tic) in enumerate(zip(axes.flat, tica_out[0].T)):
    ax.plot(x, tic)
    ax.set_ylabel('IC {}'.format(i + 1))
axes[-1].set_xlabel('time / ns')
fig.tight_layout()
# plt.savefig('ics_update.png')

# %%
cluster = pyemma.coordinates.cluster_kmeans(
    tica_out, k=20, max_iter=200, stride=1, fixed_seed=1)
dtrajs_concatenated = np.concatenate(cluster.dtrajs)
# Out:
# initialize kmeans++ centers:   0%|                       | 0/20 [00:00<?, ?it/s]

# %%
fig, ax = plt.subplots(figsize=(4, 4))
pyemma.plots.plot_density(
    *tica_concatenated[:, :2].T, ax=ax, cbar=False, alpha=0.3)
ax.scatter(*cluster.clustercenters[:, :2].T, s=5, c='C1')
ax.set_xlabel('IC 1')
ax.set_ylabel('IC 2')
fig.tight_layout()
# plt.savefig('cluster_update.png',dpi=300)

# %%
its = pyemma.msm.its(cluster.dtrajs, lags=300, nits=10, errors='bayes')
pyemma.plots.plot_implied_timescales(its, units='ns', dt=0.1);
# plt.savefig('its_update.png',dpi=300)
