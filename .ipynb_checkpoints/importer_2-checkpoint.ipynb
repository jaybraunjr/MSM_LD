# %%
import pyemma.coordinates as coor
import numpy as np
import pandas as pd
import time 
import matplotlib.pyplot as plt
# %matplotlib inline
import pyemma
import mdtraj as md

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx

from mpl_toolkits.axes_grid1 import make_axes_locatable

from deeptime.markov.msm import MarkovStateModel
from deeptime.plots import plot_markov_model, Network, plot_flux

# %%
from deeptime.decomposition import TICA, vamp_score_cv

# %%
arr1 = [coor.load(f'features_v1/contacts_v1_{i:03d}.npy') for i in range(9)]

# %%
arr2 = [coor.load(f'features_v1/torsions_v1_{i:03d}.npy') for i in range(9)]

# %%
arr3 = [coor.load(f'features_v1/ca_v1_{i:03d}.npy') for i in range(9)]

# %%
arr4 = [coor.load(f'features_v1/coord_v1_{i:03d}.npy') for i in range(9)]

# %%
arr5 = [coor.load(f'features_v1/ca_com_v1_{i:03d}.npy') for i in range(9)]

# %%
arr6 = [coor.load(f'arrlist_{i:03d}.npy') for i in range(9)]

# %%
arr7 = [coor.load(f't_new_{i:03d}.npy') for i in range(9)]

# %%
result = [np.concatenate([a1, a2, a3], axis=1) for a1, a2, a3 in zip(arr2, arr1, arr7)]

# %%
result = [np.concatenate([a1, a2], axis=1) for a1, a2 in zip(arr5, arr4)]

# %%
np.shape(result[0])
# Out:
# (10001, 156)

# %%
arr1[0]
# Out:
# array([[19.,  0.,  0., ..., 13.,  0.,  0.],
#        [41.,  0.,  0., ..., 18.,  0.,  0.],
#        [24.,  6.,  0., ...,  8.,  0.,  0.],
#        ...,
#        [52., 18.,  0., ..., 55., 11.,  0.],
#        [70., 37.,  1., ..., 56., 10.,  0.],
#        [57., 21., 14., ..., 43.,  1.,  0.]], dtype=float32)

# %%
arr5[0]
# Out:
# array([[0.14719187, 0.16049287, 0.14558569, ..., 0.14885809, 0.13635482,
#         0.14499463],
#        [0.1471439 , 0.16542453, 0.15032953, ..., 0.15103337, 0.13777797,
#         0.146734  ],
#        [0.14192535, 0.16067027, 0.15265016, ..., 0.14751597, 0.13520955,
#         0.1453715 ],
#        ...,
#        [0.15642166, 0.17694552, 0.16216765, ..., 0.1784294 , 0.16125241,
#         0.17456703],
#        [0.15667279, 0.17025304, 0.15874   , ..., 0.17766377, 0.16096297,
#         0.17192146],
#        [0.15342948, 0.1671324 , 0.15900071, ..., 0.17369312, 0.15879874,
#         0.1701757 ]], dtype=float32)

# %%
np.shape(result[0])
# Out:
# (10001, 84)

# %%
dim = 20
lags = [5, 10,100, 200]  # ps

# %%
fig, axes = plt.subplots(1, 4, figsize=(12, 3), sharey=True)

labels = ['backbone\ntorsions', 'heavy Atom\ndistances']

tica_estimator = TICA(lagtime=lags[0], dim=dim)

for ax, lag in zip(axes.flat, lags):
    tica_estimator.lagtime = lag
    torsions_scores = vamp_score_cv(tica_estimator, trajs=tot_data, blocksplit=False, n=3)
    scores = [torsions_scores.mean()]
    errors = [torsions_scores.std()]
#     distances_scores = vamp_score_cv(tica_estimator, trajs=heavy_atom_distances, blocksplit=False, n=3)
#     scores += [distances_scores.mean()]
#     errors += [distances_scores.std()]
    ax.bar(labels, scores, yerr=errors, color=['C0', 'C1', 'C2'])
    ax.set_title(r'lag time $\tau$={}ps'.format(lag))

axes[0].set_ylabel('VAMP2 score')
fig.tight_layout()

# %%
tica_estimator = TICA(lagtime=20, var_cutoff=0.95)
tica = tica_estimator.fit_fetch(tot_data)
# Out:
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 0: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 1: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 2: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 3: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 4: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 5: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 6: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 7: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 8: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 9: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 10: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 11: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 12: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 13: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 14: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 15: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 16: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 17: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 18: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 19: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 20: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 21: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 22: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 23: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 24: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 25: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 26: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 27: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 28: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 29: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 30: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 31: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 32: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 33: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 34: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 35: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 36: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 37: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 38: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 39: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 40: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 41: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 42: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 43: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 44: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 45: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 46: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 47: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 48: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 49: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 50: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 51: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 52: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 53: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 54: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 55: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 56: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 57: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 58: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 59: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 60: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 61: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 62: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 63: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 64: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 65: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 66: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 67: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 68: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 69: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 70: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 71: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 72: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 73: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 74: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 75: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 76: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 77: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 78: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 79: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 80: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 81: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 82: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 83: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 84: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 85: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 86: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 87: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 88: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 89: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 90: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 91: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 92: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 93: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 94: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 95: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 96: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 97: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 98: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 99: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 100: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 101: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 102: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 103: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 104: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 105: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 106: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 107: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 108: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 109: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 110: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 111: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 112: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 113: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 114: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 115: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 116: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 117: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 118: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 119: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 120: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 121: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 122: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 123: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 124: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 125: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 126: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 127: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 128: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 129: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 130: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 131: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 132: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 133: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 134: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 135: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 136: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 137: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 138: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 139: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 140: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 141: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 142: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 143: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 144: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 145: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 146: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 147: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 148: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 149: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 150: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 151: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 152: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 153: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 154: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 155: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 156: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 157: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 158: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 159: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 160: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 161: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 162: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 163: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 164: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 165: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 166: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 167: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 168: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 169: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 170: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 171: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 172: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 173: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 174: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 175: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 176: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# ...
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 942: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 943: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 944: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 945: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 946: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 947: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 948: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 949: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 950: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 951: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 952: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 953: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 954: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 955: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 956: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 957: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 958: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 959: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 960: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 961: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 962: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 963: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 964: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 965: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 966: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 967: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 968: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 969: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 970: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 971: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 972: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 973: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 974: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 975: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 976: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 977: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 978: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 979: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 980: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 981: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 982: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 983: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 984: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 985: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 986: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 987: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:424: UserWarning: Skipping trajectory 988: Not enough data (length=11) to satisfy lagtime=20.
#   warnings.warn(f"Skipping trajectory {i}: {e}", UserWarning)
# ---------------------------------------------------------------------------
# TrajectoryTooShortError                   Traceback (most recent call last)
# Cell In[69], line 2
#       1 tica_estimator = TICA(lagtime=20, var_cutoff=0.95)
# ----> 2 tica = tica_estimator.fit_fetch(tot_data)
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/base.py:307, in Estimator.fit_fetch(self, data, **kwargs)
#     292 def fit_fetch(self, data, **kwargs):
#     293     r""" Fits the internal model on data and subsequently fetches it in one call.
#     294
#     295     Parameters
#    (...)
#     305         The estimated model.
#     306     """
# --> 307     self.fit(data, **kwargs)
#     308     return self.fetch_model()
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/base.py:417, in _ImmutableInputData.__call__(self, *args, **kwargs)
#     415 # here we invoke the immutable setting context manager.
#     416 with self:
# --> 417     return self.fit_method(*args, **kwargs)
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/decomposition/_vamp.py:423, in VAMP.fit(self, data, *args, **kw)
#     421     self.fit_from_covariances(data)
#     422 else:
# --> 423     self.fit_from_timeseries(data, weights=kw.pop('weights', None))
#     424 return self
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/decomposition/_vamp.py:279, in VAMP.fit_from_timeseries(self, data, weights)
#     263 def fit_from_timeseries(self, data, weights=None):
#     264     r""" Estimates a :class:`CovarianceKoopmanModel` directly from time-series data using the :class:`Covariance`
#     265     estimator. For parameters `dim`, `scaling`, `epsilon`.
#     266
#    (...)
#     277         Reference to self.
#     278     """
# --> 279     dataset = to_dataset(data, lagtime=self.lagtime)
#     280     self._covariance_estimator = self.covariance_estimator(lagtime=self.lagtime)
#     281     x, y = dataset[:]
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/types.py:256, in to_dataset(data, lagtime)
#     254 if isinstance(data, list) and len(data) > 0 and isinstance(data[0], np.ndarray):
#     255     data = ensure_timeseries_data(data)
# --> 256     return TrajectoriesDataset.from_numpy(lagtime, data)
#     257 assert hasattr(data, '__len__') and len(data) > 0, "Data is empty."
#     258 assert is_timelagged_dataset(data), \
#     259     "Data is not a time-lagged dataset, i.e., yielding tuples of instantaneous and time-lagged data. " \
#     260     "In case of multiple trajectories, deeptime.util.data.TrajectoriesDataset may be used."
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/deeptime/util/data.py:427, in TrajectoriesDataset.from_numpy(lagtime, data)
#     425 if len(individual_datasets) > 0:
#     426     return TrajectoriesDataset(individual_datasets)
# --> 427 raise TrajectoryTooShortError(f"All provided trajectories were too short "
#     428                               f"for the provided lagtime of {lagtime}.")
#
# TrajectoryTooShortError: All provided trajectories were too short for the provided lagtime of 20.

# %%
tica.output_dimension
# Out:
# 17

# %%
traj=np.concatenate(tot_data)

# %%
np.shape(traj)
# Out:
# (98312, 203)

# %%
tica_estimator = TICA(lagtime=1, var_cutoff=0.95)
tica = tica_estimator.fit(tot_data)

# %%
out_cont = np.concatenate(tot_data)

# %%
np.shape(out_cont)
# Out:
# (98374, 49)

# %%
import pyemma.util.contexts

# %%
labels = ['backbone\ntorsions']

# %%
def score_cv(data, dim, lag, number_of_splits=10, validation_fraction=0.5):
    """Compute a cross-validated VAMP2 score.

    We randomly split the list of independent trajectories into
    a training and a validation set, compute the VAMP2 score,
    and repeat this process several times.

    Parameters
    ----------
    data : list of numpy.ndarrays
        The input data.
    dim : int
        Number of processes to score; equivalent to the dimension
        after projecting the data with VAMP2.
    lag : int
        Lag time for the VAMP2 scoring.
    number_of_splits : int, optional, default=10
        How often do we repeat the splitting and score calculation.
    validation_fraction : int, optional, default=0.5
        Fraction of trajectories which should go into the validation
        set during a split.
    """
    # we temporarily suppress very short-lived progress bars
    with pyemma.util.contexts.settings(show_progress_bars=False):
        nval = int(len(data) * validation_fraction)
        scores = np.zeros(number_of_splits)
        for n in range(number_of_splits):
            ival = np.random.choice(len(data), size=nval, replace=False)
            vamp = pyemma.coordinates.vamp(
                [d for i, d in enumerate(data) if i not in ival], lag=lag, dim=dim)
            scores[n] = vamp.score([d for i, d in enumerate(data) if i in ival])
    return scores


# dim = 10

# fig, axes = plt.subplots(1, 3, figsize=(12, 3), sharey=True)
# for ax, lag in zip(axes.flat, [5, 10, 20]):
#     data_scores = score_cv(tot_data, lag=lag, dim=dim)
#     scores = [data_scores.mean()]
#     errors = [data_scores.std()]
# #     positions_scores = score_cv(positions_data, lag=lag, dim=dim)
# #     scores += [positions_scores.mean()]
# #     errors += [positions_scores.std()]
# #     distances_scores = score_cv(distances_data, lag=lag, dim=dim)
# #     scores += [distances_scores.mean()]
# #     errors += [distances_scores.std()]
#     ax.bar(labels, scores, yerr=errors, color=['C0'])
#     ax.set_title(r'lag time $\tau$={:.1f}ns'.format(lag * 0.1))
#     if lag == 5:
#         # save for later
#         vamp_bars_plot = dict(
#             labels=labels, scores=scores, errors=errors, dim=dim, lag=lag)
# axes[0].set_ylabel('VAMP2 score')
# fig.tight_layout()

# %%
lags = [1, 10, 30, 50, 75, 100 ]
dims = [i + 1 for i in range(40)]

fig, ax = plt.subplots()
for i, lag in enumerate(lags):
    scores_ = np.array([score_cv(tot_data, dim, lag)
                        for dim in dims])
    scores = np.mean(scores_, axis=1)
    errors = np.std(scores_, axis=1, ddof=1)
    color = 'C{}'.format(i)
    ax.fill_between(dims, scores - errors, scores + errors, alpha=0.3, facecolor=color)
    ax.plot(dims, scores, '--o', color=color, label='lag={:.1f}ns'.format(lag * 0.1))
ax.legend()
ax.set_xlabel('number of dimensions')
ax.set_ylabel('VAMP2 score')
fig.tight_layout()
plt.savefig('lag_vamp.png',dpi=300)

# %%
np.shape(tot_data)
# Out:
# (989, 11, 203)

# %%
distance_features = np.concatenate(tot_data)

# %%
np.shape(distance_features)
# Out:
# (98312, 203)

# %%
distance_features
# Out:
# array([[ 0.48988724,  0.6028862 ,  0.670887  , ...,  1.5398865 ,
#          1.6718864 ,  1.0888863 ],
#        [ 0.25152206,  0.3755226 ,  0.48352242, ...,  0.94052315,
#          1.0055218 ,  0.7805233 ],
#        [ 0.3697033 ,  0.50170326,  0.62070465, ...,  1.1777039 ,
#          1.3077049 ,  0.7977047 ],
#        ...,
#        [-0.06173849,  0.06326151,  0.2912612 , ...,  0.9072614 ,
#          0.8172612 ,  1.0692616 ],
#        [-0.11392069,  0.01207924,  0.2400794 , ...,  1.0640793 ,
#          0.9900794 ,  1.1640792 ],
#        [ 0.0034318 ,  0.11143208,  0.35443163, ...,  1.1274319 ,
#          1.0694318 ,  1.3054318 ]], dtype=float32)

# %%
tica_dev = pyemma.coordinates.tica(arr6, var_cutoff=0.1)
tica_out = tica_dev.get_output()
tica_concatenated = np.concatenate(tica_out)
# Out:
# calculate covariances:   0%|                              | 0/9 [00:00<?, ?it/s]
# getting output of TICA:   0%|                             | 0/9 [00:00<?, ?it/s]

# %%
tica_dev.dimension()
# Out:
# 4

# %%
np.shape(tica_concatenated)
# Out:
# (98374, 4)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
pyemma.plots.plot_feature_histograms(
    tica_concatenated,
    ax=axes[0],
#     feature_labels=['IC1', 'IC2', 'IC3'],
    ylog=True, ignore_dim_warning=True)
pyemma.plots.plot_density(*tica_concatenated[:, :2].T, ax=axes[1], logscale=True)
axes[1].set_xlabel('IC 1')
axes[1].set_ylabel('IC 2')
fig.tight_layout()
# plt.savefig('tica_update.png', dpi= 300)

# %%
np.shape(tica_concatenated)
# Out:
# (98374, 17)

# %%
tot_cont = np.concatenate(result)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
pyemma.plots.plot_feature_histograms(
    tot_cont,
    ax=axes[0],
#     feature_labels=['IC1', 'IC2', 'IC3'],
    ylog=True, ignore_dim_warning=True)
pyemma.plots.plot_density(*tot_cont[:, :2].T, ax=axes[1], logscale=True)
axes[1].set_xlabel('IC 1')
axes[1].set_ylabel('IC 2')
fig.tight_layout()
# plt.savefig('tica2.png')

# %%
np.shape(tica_out)
# Out:
# (9,)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
pyemma.plots.plot_feature_histograms(
    tica_concatenated,
    ax=axes[0],
#     feature_labels=['IC1', 'IC2', 'IC3'],
    ylog=True, ignore_dim_warning=True)
pyemma.plots.plot_density(*tica_concatenated[:, [1,2]].T, ax=axes[1], logscale=True)
axes[1].set_xlabel('IC 1')
axes[1].set_ylabel('IC 2')
fig.tight_layout()
# plt.savefig('tica_2_3.png',dpi=300)

# %%
fig, axes = plt.subplots(6, 1, figsize=(12, 5), sharex=True)
x = 0.1 * np.arange(tica_out[0].shape[0])
for i, (ax, tic) in enumerate(zip(axes.flat, tica_out[0].T)):
    ax.plot(x, tic)
    ax.set_ylabel('IC {}'.format(i + 1))
axes[-1].set_xlabel('time / ns')
fig.tight_layout()
# plt.savefig('ics_update.png')

# %%
n_clustercenters = [50, 75, 200, 450, 600]

scores = np.zeros((len(n_clustercenters), 5))
for n, k in enumerate(n_clustercenters):
    for m in range(5):
        with pyemma.util.contexts.settings(show_progress_bars=False):
            _cl = pyemma.coordinates.cluster_kmeans(
                tica_out, k=k, max_iter=100, stride=1)
            _msm = pyemma.msm.estimate_markov_model(_cl.dtrajs, lag=10)
            scores[n, m] = _msm.score_cv(
                _cl.dtrajs,n=1,  score_method='VAMP2', score_k=min(10, k))

fig, ax = plt.subplots()
lower, upper = pyemma.util.statistics.confidence_interval(scores.T.tolist(), conf=0.9)
ax.fill_between(n_clustercenters, lower, upper, alpha=0.3)
ax.plot(n_clustercenters, np.mean(scores, axis=1), '-o')
ax.semilogx()
ax.set_xlabel('number of cluster centers')
ax.set_ylabel('VAMP-2 score')
fig.tight_layout()
# Out:
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:242: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   or len(trajfiles) is 0)):
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:384: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   and (any(isinstance(item, (list, tuple, _string_types)) for item in inp) or len(inp) is 0)):
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:388: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   and (any(isinstance(item, _np.ndarray) for item in inp) or len(inp) is 0)):
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:242: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   or len(trajfiles) is 0)):
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:384: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   and (any(isinstance(item, (list, tuple, _string_types)) for item in inp) or len(inp) is 0)):
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:388: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   and (any(isinstance(item, _np.ndarray) for item in inp) or len(inp) is 0)):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[111], line 7
#       5 for m in range(5):
#       6     with pyemma.util.contexts.settings(show_progress_bars=False):
# ----> 7         _cl = pyemma.coordinates.cluster_kmeans(
#       8             tica_out, k=k, max_iter=100, stride=1)
#       9         _msm = pyemma.msm.estimate_markov_model(_cl.dtrajs, lag=10)
#      10         scores[n, m] = _msm.score_cv(
#      11             _cl.dtrajs,n=1,  score_method='VAMP2', score_k=min(10, k))
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/api.py:1825, in cluster_kmeans(data, k, max_iter, tolerance, stride, metric, init_strategy, fixed_seed, n_jobs, chunksize, skip, keep_data, clustercenters, **kwargs)
#    1823 cs = _check_old_chunksize_arg(chunksize, get_default_args(cluster_kmeans)['chunksize'], **kwargs)
#    1824 if data is not None:
# -> 1825     res.estimate(data, chunksize=cs)
#    1826 else:
#    1827     res.chunksize = cs
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/data/_base/transformer.py:215, in StreamingEstimationTransformer.estimate(self, X, **kwargs)
#     214 def estimate(self, X, **kwargs):
# --> 215     super(StreamingEstimationTransformer, self).estimate(X, **kwargs)
#     216     # we perform the mapping to memory exactly here, because a StreamingEstimator on its own
#     217     # has not output to be mapped. Only the combination of Estimation/Transforming has this feature.
#     218     if self.in_memory and not self._mapping_to_mem_active:
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/data/_base/streaming_estimator.py:44, in StreamingEstimator.estimate(self, X, chunksize, **kwargs)
#      42 # run estimation
#      43 try:
# ---> 44     super(StreamingEstimator, self).estimate(X, **kwargs)
#      45 except NotConvergedWarning as ncw:
#      46     self.logger.info(
#      47         "Presumably finished estimation. Message: %s" % ncw)
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/_base/estimator.py:407, in Estimator.estimate(self, X, **params)
#     405 if params:
#     406     self.set_params(**params)
# --> 407 self._model = self._estimate(X)
#     408 # ensure _estimate returned something
#     409 assert self._model is not None
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/clustering/kmeans.py:216, in KmeansClustering._estimate(self, iterable, **kw)
#     213         self._collect_data(X, first_chunk, it.last_chunk)
#     214         if not resume_centers:
#     215             # initialize cluster centers
# --> 216             self._initialize_centers(X, itraj, it.pos, it.last_chunk)
#     217         first_chunk = False
#     218 self.initial_centers_ = self.clustercenters[:]
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/coordinates/clustering/kmeans.py:319, in KmeansClustering._initialize_centers(self, X, itraj, t, last_chunk)
#     317     context = nullcontext()
#     318 with context:
# --> 319     self.clustercenters = self._inst.init_centers_KMpp(self._in_memory_chunks, self.fixed_seed, self.n_jobs,
#     320                                                        callback)
#
# KeyboardInterrupt:

# %%
cluster = pyemma.coordinates.cluster_kmeans(
    tica_out, k=4, max_iter=200, stride=1, fixed_seed=1)
dtrajs_concatenated = np.concatenate(cluster.dtrajs)

# %%
data_concatenated = np.concatenate(arr5)

# %%
cluster = pyemma.coordinates.cluster_kmeans(arr5, k=75, max_iter=50, stride=10)
dtrajs_concatenated = np.concatenate(cluster.dtrajs)
# Out:
# initialize kmeans++ centers:   0%|                       | 0/75 [00:00<?, ?it/s]
# kmeans iterations:   0%|                                 | 0/50 [00:00<?, ?it/s]
# getting output of KmeansClustering:   0%|                 | 0/9 [00:00<?, ?it/s]

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4), sharey=True)
pyemma.plots.plot_implied_timescales(
    pyemma.msm.timescales_hmsm(
        cluster.dtrajs, 3, lags=[1, 2, 3, 8], errors='bayes', nsamples=50),
    ax=axes[0], units='ps')
pyemma.plots.plot_implied_timescales(
    pyemma.msm.timescales_hmsm(
        cluster.dtrajs, 6, lags=[1, 2, 3, 8], errors='bayes', nsamples=50),
    ax=axes[1], units='ps')
fig.tight_layout()
# Out:
# estimating BayesianHMSM:   0%|                            | 0/4 [00:00<?, ?it/s]
# estimating BayesianHMSM:   0%|                            | 0/4 [00:00<?, ?it/s]

# %%
hmm_6 = pyemma.msm.bayesian_hidden_markov_model(cluster.dtrajs, 3, lag=2, dt_traj='1 ps', nsamples=50)
pyemma.plots.plot_cktest(hmm_6.cktest(mlags=6), units='ps');
# Out:
# Sampling HMSMs:   0%|                                    | 0/50 [00:00<?, ?it/s]
# estimating BayesianHMSM:   0%|                            | 0/5 [00:00<?, ?it/s]

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4), sharex=True, sharey=True)
for hmm, ax in zip([hmm_4, hmm_6], axes.flat):
    _, _, misc = pyemma.plots.plot_state_map(
        *tica_concatenated[:,:2].T,
        hmm.metastable_assignments[dtrajs_concatenated],
        ax=ax)
    ax.set_title('HMM with {} hidden states'.format(hmm.nstates))
    ax.set_xlabel('$\Phi$')
    misc['cbar'].set_ticklabels(range(1, hmm.nstates + 1))
axes[0].set_ylabel('$\Psi$')
fig.tight_layout()

# %%
A = [0]
B = [2]
flux = pyemma.msm.tpt(hmm_6, A, B)

highest_membership = hmm_6.metastable_distributions.argmax(1)
coarse_state_centers = cluster.clustercenters[hmm_4.observable_set[highest_membership]]

# %%
pyemma.plots.plot_markov_model(hmm);

# %%
fig, ax = plt.subplots(figsize=(4, 4))
pyemma.plots.plot_density(
    *tica_concatenated[:, :2].T, ax=ax, cbar=False, alpha=0.3)
ax.scatter(*cluster.clustercenters[:, :2].T, s=5, c='C1')
ax.set_xlabel('IC 1')
ax.set_ylabel('IC 2')
fig.tight_layout()
# plt.savefig('cluster_update.png',dpi=300)

# %%
its = pyemma.msm.its(cluster.dtrajs, lags=100, nits=10, errors='bayes')
pyemma.plots.plot_implied_timescales(its, units='ns', dt=0.1);
# plt.savefig('its_update.png',dpi=300)
# Out:
# estimating BayesianMSM:   0%|                            | 0/12 [00:00<?, ?it/s]
# Exception ignored in: <built-in method acquire of _thread.lock object at 0x14f0c1261cf0>
# Traceback (most recent call last):
#   File "/uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/multiprocess/popen_fork.py", line 66, in _launch
#     self.pid = os.fork()
# KeyboardInterrupt:

# %%
pc_dev = pyemma.coordinates.pca(tot_data, dim=4)
# Out:
# calc mean+cov:   0%|                                      | 0/9 [00:00<?, ?it/s]

# %%
pca_out=pc_dev.get_output()
# Out:
# getting output of PCA:   0%|                              | 0/9 [00:00<?, ?it/s]

# %%
pca_concatenated = np.concatenate(pca_out)

# %%
msm = pyemma.msm.bayesian_markov_model(cluster.dtrajs, lag=50, dt_traj='0.1 ns')
print('fraction of states used = {:.2f}'.format(msm.active_state_fraction))
print('fraction of counts used = {:.2f}'.format(msm.active_count_fraction))
# Out:
# pyemma.msm.estimators.bayesian_msm.BayesianMSM[21181]: compute stat. inefficienc
# pyemma.msm.estimators.bayesian_msm.BayesianMSM[21181]: Sampling MSMs:   0%| | 0/
# fraction of states used = 1.00
# fraction of counts used = 1.00

# %%
msm
# Out:
# BayesianMSM(conf=0.95, connectivity='largest', core_set=None,
#       count_mode='effective', dt_traj='0.1 ns', lag=200,
#       milestoning_method='last_core', mincount_connectivity='1/n',
#       nsamples=100, nsteps=7, reversible=True, show_progress=True,
#       sparse=False, statdist_constraint=None)

# %%
msm = pyemma.msm.estimate_markov_model(cluster.dtrajs, lag=200, dt_traj='0.1 ns')
print('fraction of states used = {:.2f}'.format(msm.active_state_fraction))
print('fraction of counts used = {:.2f}'.format(msm.active_count_fraction))
# Out:
# fraction of states used = 1.00
# fraction of counts used = 1.00

# %%
mlmsm = pyemma.msm.MaximumLikelihoodMSM(lag=100) 
# print('fraction of states used = {:.2f}'.format(mlmsm.active_state_fraction))
# print('fraction of counts used = {:.2f}'.format(mlmsm.active_count_fraction))

# %%
mlmsm.active_state_fraction
# Out:
# 1.0

# %%
# Estimate the MSM from the data
mlmsm.fit(dtrajs_concatenated)

# Now you can access the properties of the estimated MSM
print(mlmsm.transition_matrix)  # The estimated transition matrix
print(mlmsm.stationary_distribution)  # The estimated stationary distribution
# Out:
# [[9.47158527e-02 9.84829603e-03 1.01744508e-03 ... 3.78028289e-02
#   1.26865551e-02 4.77896694e-02]
#  [2.30939979e-03 1.97042933e-01 0.00000000e+00 ... 2.50411325e-03
#   0.00000000e+00 1.31100836e-04]
#  [9.12863555e-04 0.00000000e+00 1.85461325e-01 ... 9.82741217e-03
#   0.00000000e+00 0.00000000e+00]
#  ...
#  [3.60117395e-02 1.01726883e-02 1.04343182e-02 ... 6.68662677e-02
#   0.00000000e+00 5.90894559e-02]
#  [6.90016036e-03 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   5.78414838e-01 0.00000000e+00]
#  [1.96196601e-02 2.29522300e-04 0.00000000e+00 ... 2.54652324e-02
#   0.00000000e+00 6.04770020e-02]]
# [0.00932949 0.03978504 0.01039831 0.02625645 0.03517339 0.02941348
#  0.02117057 0.03073414 0.01671222 0.03574251 0.01198149 0.00881013
#  0.01634931 0.01472926 0.01410603 0.02222459 0.02971263 0.01884329
#  0.00822216 0.0103536  0.02132962 0.00857501 0.02256286 0.03320395
#  0.01802999 0.00781992 0.01084728 0.02595328 0.02297043 0.01333828
#  0.0167947  0.03475144 0.01347775 0.01091452 0.02023508 0.02983505
#  0.04324367 0.02485455 0.03265793 0.02423146 0.01745559 0.01903282
#  0.00450073 0.02074947 0.03021077 0.00663988 0.00606446 0.0097935
#  0.01715309 0.02272481]

# %%
hmsm = pyemma.msm.estimate_hidden_markov_model(cluster.dtrajs,nstates=3 ,lag=100, dt_traj='0.1 ns')
# print('fraction of states used = {:.2f}'.format(msm.active_state_fraction))
# print('fraction of counts used = {:.2f}'.format(msm.active_count_fraction))

# %%
# Define lag time and number of hidden states
lag = 10
n_hidden_states = 4

# Estimate hidden Markov model
hmm = pyemma.msm.estimate_hidden_markov_model(cluster.dtrajs, n_hidden_states, lag)

# Get implied timescales
its = hmm.timescales()

# %%
# Define the range of lag times
lags = np.arange(20, 200, 5)

# Calculate the implied timescales for each lag time
its = pyemma.msm.timescales_hmsm(cluster.dtrajs, n_hidden_states, lags=lags)

# Get the timescales as an array
its_array = its.get_timescales()

# Plot the results
fig, ax = plt.subplots()
for i in range(n_hidden_states):
    ax.plot(lags, its_array[:, i], label='State {}'.format(i+1))
ax.set_xlabel('Lag time')
ax.set_ylabel('Implied timescales')
ax.legend()
plt.grid()
plt.show()
# Out:
# estimating MaximumLikelihoodHMSM:   0%|                  | 0/36 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[519], line 13
#      11 fig, ax = plt.subplots()
#      12 for i in range(n_hidden_states):
# ---> 13     ax.plot(lags, its_array[:, i], label='State {}'.format(i+1))
#      14 ax.set_xlabel('Lag time')
#      15 ax.set_ylabel('Implied timescales')
#
# IndexError: index 3 is out of bounds for axis 1 with size 3

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4), sharey=True)
pyemma.plots.plot_implied_timescales(
    pyemma.msm.timescales_hmsm(
        cluster.dtrajs, 4, lags=[20, 30, 40, 75], errors='bayes', nsamples=50),
    ax=axes[0], units='ps')
pyemma.plots.plot_implied_timescales(
    pyemma.msm.timescales_hmsm(
        cluster.dtrajs, 6, lags=[20, 30, 40, 75], errors='bayes', nsamples=50),
    ax=axes[1], units='ps')
fig.tight_layout()
# Out:
# estimating BayesianHMSM:   0%|                            | 0/4 [00:00<?, ?it/s]
# estimating BayesianHMSM:   0%|                            | 0/4 [00:00<?, ?it/s]

# %%
hmsm
# Out:
# MaximumLikelihoodHMSM(accuracy=0.001, connectivity=None, dt_traj='0.1 ns',
#            lag=100, maxit=1000, mincount_connectivity=0.3333333333333333,
#            msm_init='largest-strong', nstates=3, observe_nonempty=True,
#            reversible=True, separate=None, stationary=False, stride=1)

# %%
import pyemma.msm as msm2

# %%
import pyemma.plots as mplt2

# %%
msm_obj = msm2.estimate_markov_model(cluster.dtrajs, lag=100)

# %%
print(msm)
# Out:
# BayesianMSM(conf=0.95, connectivity='largest', core_set=None,
#       count_mode='effective', dt_traj='0.1 ns', lag=100,
#       milestoning_method='last_core', mincount_connectivity='1/n',
#       nsamples=100, nsteps=8, reversible=True, show_progress=True,
#       sparse=False, statdist_constraint=None)

# %%
print(msm_obj)
# Out:
# MaximumLikelihoodMSM(connectivity='largest', core_set=None,
#            count_mode='sliding', dt_traj='1 step', lag=100, maxerr=1e-08,
#            maxiter=1000000, milestoning_method='last_core',
#            mincount_connectivity='1/n', reversible=True, score_k=10,
#            score_method='VAMP2', sparse=False, statdist_constraint=None)

# %%
print(np.shape(msm_obj.transition_matrix))
# Out:
# (75, 75)

# %%
mplt2.plot_network(msm_obj.transition_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 mplt2.plot_network(msm_obj.transition_matrix)
#
# NameError: name 'mplt2' is not defined

# %%
def its_separation_err(ts, ts_err):
    """
    Error propagation from ITS standard deviation to timescale separation.
    """
    return ts[:-1] / ts[1:] * np.sqrt(
        (ts_err[:-1] / ts[:-1])**2 + (ts_err[1:] / ts[1:])**2)


nits = 10

timescales_mean = msm.sample_mean('timescales', k=nits)
timescales_std = msm.sample_std('timescales', k=nits)

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].errorbar(
    range(1, nits + 1),
    timescales_mean,
    yerr=timescales_std,
    fmt='.', markersize=10)
axes[1].errorbar(
    range(1, nits),
    timescales_mean[:-1] / timescales_mean[1:],
    yerr=its_separation_err(
        timescales_mean,
        timescales_std),
    fmt='.',
    markersize=10,
    color='C0')

for i, ax in enumerate(axes):
    ax.set_xticks(range(1, nits + 1))
    ax.grid(True, axis='x', linestyle=':')

axes[0].axhline(msm.lag * 0.1, lw=1.5, color='k')
axes[0].axhspan(0, msm.lag * 0.1, alpha=0.3, color='k')
axes[0].set_xlabel('implied timescale index')
axes[0].set_ylabel('implied timescales / ns')
axes[1].set_xticks(range(1, nits))
# axes[1].set_xticklabels(
#     ["{:d}/{:d}".format(k, k + 1) for k in range(1, nits + 2)],
#     rotation=45)
axes[1].set_xlabel('implied timescale indices')
axes[1].set_ylabel('timescale separation')
fig.tight_layout()
# plt.savefig('spectral_update.png',dpi=300)
# Out:
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/msmtools/analysis/api.py:367: UserWarning: truncated eigendecomposition to contain 10 components
#   warnings.warn('truncated eigendecomposition to contain %s components' % new_k, category=UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[637], line 16
#      12 timescales_std = msm.sample_std('timescales', k=nits)
#      14 fig, axes = plt.subplots(1, 2, figsize=(10, 4))
# ---> 16 axes[0].errorbar(
#      17     range(1, nits + 1),
#      18     timescales_mean,
#      19     yerr=timescales_std,
#      20     fmt='.', markersize=10)
#      21 axes[1].errorbar(
#      22     range(1, nits),
#      23     timescales_mean[:-1] / timescales_mean[1:],
#    (...)
#      28     markersize=10,
#      29     color='C0')
#      31 for i, ax in enumerate(axes):
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:3537, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3535 x, y = np.atleast_1d(x, y)  # Make sure all the args are iterable.
#    3536 if len(x) != len(y):
# -> 3537     raise ValueError("'x' and 'y' must have the same size")
#    3539 everymask = self._errorevery_to_mask(x, errorevery)
#    3541 label = kwargs.pop("label", None)
#
# ValueError: 'x' and 'y' must have the same size

# %%
nstates = 3
cktest = msm.cktest(nstates)
pyemma.plots.plot_cktest(cktest, dt=0.1, units='ns');
# plt.savefig('cktets.png',dpi = 300)
# Out:
# estimating BayesianMSM:   0%|                             | 0/9 [00:00<?, ?it/s]
# /uufs/chpc.utah.edu/common/home/u1266568/software/pkg/miniconda3/lib/python3.9/site-packages/msmtools/analysis/api.py:367: UserWarning: truncated eigendecomposition to contain 7 components
#   warnings.warn('truncated eigendecomposition to contain %s components' % new_k, category=UserWarning)

# %%
msm.cktest
# Out:
# <bound method _MSMEstimator.cktest of BayesianMSM(conf=0.95, connectivity='largest', core_set=None,
#       count_mode='effective', dt_traj='0.1 ns', lag=30,
#       milestoning_method='last_core', mincount_connectivity='1/n',
#       nsamples=100, nsteps=7, reversible=True, show_progress=True,
#       sparse=False, statdist_constraint=None)>

# %%
eigvec = msm.eigenvectors_right()
print('The first eigenvector is one: {} (min={}, max={})'.format(
    np.allclose(eigvec[:, 0], 1, atol=1e-15), eigvec[:, 0].min(), eigvec[:, 0].max()))

fig, axes = plt.subplots(1, 4, figsize=(15, 3), sharex=True, sharey=True)
for i, ax in enumerate(axes.flat):
    pyemma.plots.plot_contour(
        *tica_concatenated[:, :2].T,
        eigvec[dtrajs_concatenated, i + 1],
        ax=ax,
        cmap='PiYG',
        cbar_label='{}. right eigenvector'.format(i + 2),
        mask=True)
    ax.set_xlabel('IC 1')
axes[0].set_ylabel('IC 2')
fig.tight_layout()
# plt.savefig('righ_eigen.png',dpi=300)
# Out:
# The first eigenvector is one: True (min=0.9999999999999908, max=1.0000000000001228)

# %%
plt.plot(eigvec[40])

# %%
eigvec
# Out:
# array([[ 1.00000000e+00, -3.18180402e+00,  1.14436993e+00, ...,
#          1.84986306e+00,  4.39674296e-01,  4.90075661e-02],
#        [ 1.00000000e+00, -6.99086032e+00, -1.63608379e-01, ...,
#         -1.55110301e+01,  1.08970300e+00, -1.36935435e-01],
#        [ 1.00000000e+00,  4.49185520e-02,  2.44008460e+00, ...,
#          7.62182165e-04, -1.49248980e-03, -2.13879344e-02],
#        ...,
#        [ 1.00000000e+00, -7.66699944e+00, -8.58308831e-02, ...,
#          3.53913555e-01,  2.77550608e+00, -1.29870459e-01],
#        [ 1.00000000e+00,  1.15357812e-01, -3.96707557e-01, ...,
#         -1.01440170e-02, -2.44859222e-02, -1.71470972e+00],
#        [ 1.00000000e+00,  4.39136468e-02,  2.42009697e+00, ...,
#         -1.82592447e-03, -1.16281214e-03, -4.84281404e-02]])

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4), sharex=True, sharey=True)
pyemma.plots.plot_contour(
    *tica_concatenated[:, :2].T,
    msm.pi[dtrajs_concatenated],
    ax=axes[0],
    mask=True,
    cbar_label='stationary distribution')
pyemma.plots.plot_free_energy(
    *tica_concatenated[:, :2].T,
    weights=np.concatenate(msm.trajectory_weights()),
    ax=axes[1],
    legacy=False)
for ax in axes.flat:
    ax.set_xlabel('IC 1')
axes[0].set_ylabel('IC 2')
axes[0].set_title('Stationary distribution', fontweight='bold')
axes[1].set_title('Reweighted free energy surface', fontweight='bold')
fig.tight_layout()
# plt.savefig('macro_energy_update.png',dpi=400)

# %%
pcca_obj = msm.pcca(3)

msm_assignments = msm.metastable_assignments

pcca=msm.pcca(3)

# %%
T = msm.transition_matrix

# %%
np.shape(T)
# Out:
# (100, 100)

# %%
K = T[[0, 1, 2]][:, [0, 1, 2]]

# print the transition probabilities between the 4 metastable states
print("Transition probabilities between the 4 metastable states:")
print(K)
# Out:
# Transition probabilities between the 4 metastable states:
# [[0.6686217  0.         0.        ]
#  [0.         0.30363263 0.        ]
#  [0.         0.         0.48005502]]

# %%
N = pcca.coarse_grained_transition_matrix

# %%
N
# Out:
# array([[9.99455878e-01, 3.24307978e-05, 5.11691247e-04],
#        [1.08063202e-05, 9.99860175e-01, 1.29018382e-04],
#        [7.93706560e-05, 4.98879121e-05, 9.99870741e-01]])

# %%
S = N[[0, 1, 2]][:, [0, 1,2 ]]

# print the transition probabilities between the 4 metastable states
print("Transition probabilities between the 4 metastable states:")
print(S)
# Out:
# Transition probabilities between the 4 metastable states:
# [[9.99455878e-01 3.24307978e-05 5.11691247e-04]
#  [1.08063202e-05 9.99860175e-01 1.29018382e-04]
#  [7.93706560e-05 4.98879121e-05 9.99870741e-01]]

# %%
np.shape(N)
# Out:
# (4, 4)

# %%
membership = pcca.memberships

# %%
pcca.metastable_assignment
# Out:
# array([2, 2, 1, 2, 2, 2, 2, 1, 2, 2, 0, 0, 0, 2, 0, 2, 1, 2, 2, 2, 2, 2,
#        2, 1, 2, 1, 2, 0, 2, 2, 1, 2, 0, 2, 2, 1, 2, 2, 0, 2, 1, 2, 0, 2,
#        2, 2, 2, 1, 2, 2, 2, 2, 2, 1, 2, 1, 1, 0, 1, 2, 1, 2, 2, 2, 2, 2,
#        1, 1, 2, 2, 2, 2, 1, 2, 2, 2, 0, 2, 2, 2, 2, 2, 0, 0, 0, 2, 2, 1,
#        2, 2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2])

# %%
prob = pcca.output_probabilities

# %%
np.shape(prob)
# Out:
# (3, 100)

# %%
pcca_prob = np.sum(prob, axis=0)

# %%
np.shape(pcca_prob)
# Out:
# (100,)

# %%
K = np.zeros((3, 3))
for i in range(3):
    for j in range(3):
        if i != j:
            K[i, j] = np.sum(T[membership[:, i] > 0, j]) / pcca_prob[i]

# %%
K
# Out:
# array([[  0.        , 841.8371794 , 785.74760272],
#        [  8.73422458,   0.        ,   7.22926819],
#        [ 27.49117081,  24.37857158,   0.        ]])

# %%
K /= np.sum(K, axis=1)[:, np.newaxis]

# print the transition matrix
print(K)
# Out:
# [[0.         0.51723092 0.48276908]
#  [0.54713744 0.         0.45286256]
#  [0.530004   0.469996   0.        ]]

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
for i, ax in enumerate(axes.flat):
    pyemma.plots.plot_contour(
        *tica_concatenated[:, :2].T, msm.metastable_distributions[i][cluster.dtrajs[0]], ax=ax, cmap='afmhot_r',
        mask=True, method='nearest', cbar_label='metastable distribution {}'.format(i + 1))
    ax.scatter(*cluster.clustercenters.T, s=15, c='k')
    ax.set_xlabel('$x$')
    ax.set_xlim(-4, 4)
    ax.set_ylim(-4, 4)
    ax.set_aspect('equal')
axes[0].set_ylabel('$y$')
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 3
#       1 fig, axes = plt.subplots(1, 2, figsize=(10, 4))
#       2 for i, ax in enumerate(axes.flat):
# ----> 3     pyemma.plots.plot_contour(
#       4         *tica_concatenated[:, :2].T, msm.metastable_distributions[i][cluster.dtrajs[0]], ax=ax, cmap='afmhot_r',
#       5         mask=True, method='nearest', cbar_label='metastable distribution {}'.format(i + 1))
#       6     ax.scatter(*cluster.clustercenters.T, s=15, c='k')
#       7     ax.set_xlabel('$x$')
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/plots/plots2d.py:801, in plot_contour(xall, yall, zall, ax, cmap, ncontours, vmin, vmax, levels, cbar, cax, cbar_label, cbar_orientation, norm, nbins, method, mask, **kwargs)
#     691 def plot_contour(
#     692         xall, yall, zall, ax=None, cmap=None,
#     693         ncontours=100, vmin=None, vmax=None, levels=None,
#     694         cbar=True, cax=None, cbar_label=None,
#     695         cbar_orientation='vertical', norm=None, nbins=100,
#     696         method='nearest', mask=False, **kwargs):
#     697     """Plot a two-dimensional contour map by interpolating
#     698     scattered data on a grid.
#     699
#    (...)
#     799
#     800     """
# --> 801     x, y, z = get_grid_data(
#     802         xall, yall, zall, nbins=nbins, method=method)
#     803     if vmin is None:
#     804         vmin = _np.min(zall[zall > -_np.inf])
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/pyemma/plots/plots2d.py:194, in get_grid_data(xall, yall, zall, nbins, method)
#     189 from scipy.interpolate import griddata
#     190 x, y = _np.meshgrid(
#     191     _np.linspace(xall.min(), xall.max(), nbins),
#     192     _np.linspace(yall.min(), yall.max(), nbins),
#     193     indexing='ij')
# --> 194 z = griddata(
#     195     _np.hstack([xall[:,None], yall[:,None]]),
#     196     zall, (x, y), method=method)
#     197 return x, y, z
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/scipy/interpolate/_ndgriddata.py:261, in griddata(points, values, xi, method, fill_value, rescale)
#     259     return ip(xi)
#     260 elif method == 'nearest':
# --> 261     ip = NearestNDInterpolator(points, values, rescale=rescale)
#     262     return ip(xi)
#     263 elif method == 'linear':
#
# File ~/software/pkg/miniconda3/lib/python3.9/site-packages/scipy/interpolate/_ndgriddata.py:88, in NearestNDInterpolator.__init__(self, x, y, rescale, tree_options)
#      87 def __init__(self, x, y, rescale=False, tree_options=None):
# ---> 88     NDInterpolatorBase.__init__(self, x, y, rescale=rescale,
#      89                                 need_contiguous=False,
#      90                                 need_values=False)
#      91     if tree_options is None:
#      92         tree_options = dict()
#
# File interpnd.pyx:78, in scipy.interpolate.interpnd.NDInterpolatorBase.__init__()
#
# File interpnd.pyx:192, in scipy.interpolate.interpnd._check_init_shape()
#
# ValueError: different number of values and points

# %%
mfpt = np.zeros((nstates, nstates))
for i in range(nstates):
    for j in range(nstates):
        mfpt[i, j] = msm.mfpt(
            msm.metastable_sets[i],
            msm.metastable_sets[j])

from pandas import DataFrame
print('MFPT / steps:')
DataFrame(np.round(mfpt, decimals=2), index=range(1, nstates + 1), columns=range(1, nstates + 1))
# Out:
# MFPT / steps:
#           1        2        3
# 1      0.00  6755.58  1158.39
# 2  17441.12     0.00  1098.58
# 3  18770.55  8014.34     0.00

# %%
nstates = 3
msm.pcca(nstates)
for i, s in enumerate(msm.metastable_sets):
    print('π_{} = {:f}'.format(i + 1, msm.pi[s].sum()))
# Out:
# π_1 = 0.003990
# π_2 = 0.136643
# π_3 = 0.859367

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 3))
for i, ax in enumerate(axes.flat):
    pyemma.plots.plot_contour(
        *tica_concatenated[:, :2].T,
        msm.metastable_distributions[i][dtrajs_concatenated],
        ax=ax,
        cmap='afmhot_r',
        mask=True,
        cbar_label='metastable distribution {}'.format(i + 1))
    ax.set_xlabel('$\Phi$')
axes[0].set_ylabel('$\Psi$')
fig.tight_layout()
# plt.savefig('meta_update.png',dpi=300)

# %%
metastable_traj = msm.metastable_assignments[dtrajs_concatenated]
highest_membership = msm.metastable_distributions.argmax(1)
coarse_state_centers = cluster.clustercenters[msm.active_set[highest_membership]]

# %%
mfpt = np.zeros((nstates, nstates))
for i in range(nstates):
    for j in range(nstates):
        mfpt[i, j] = msm.mfpt(
            msm.metastable_sets[i],
            msm.metastable_sets[j])

inverse_mfpt = np.zeros_like(mfpt)
nz = mfpt.nonzero()
inverse_mfpt[nz] = 1.0 / mfpt[nz]

# %%
metastable_traj = msm.metastable_assignments[dtrajs_concatenated]

fig, ax = plt.subplots(figsize=(5, 4))
_, _, misc = pyemma.plots.plot_state_map(
    *tica_concatenated[:, :2].T, metastable_traj, ax=ax)
ax.set_xlabel('IC 1')
ax.set_ylabel('IC 2')
misc['cbar'].set_ticklabels([r'$\mathcal{S}_%d$' % (i + 1)
                             for i in range(nstates)])
fig.tight_layout()
# fig.savefig('pcca_update.png',dpi=400)

# %%
(msm.metastable_assignments)
# Out:
# array([1, 1, 2, 1, 3, 1, 0, 0, 2, 1, 1, 3, 1, 0, 1, 3, 0, 0, 1, 2, 2, 1,
#        1, 0, 0, 2, 1, 2, 3, 0, 3, 0, 1, 1, 1, 1, 2, 1, 1, 1, 0, 2, 3, 1,
#        1, 3, 0, 1, 3, 1])

# %%
n_macrostates = 4  # or however many macrostates you have
mapping = {0: 3, 1: 2, 2: 0, 3: 1}  # map old states to new states

# Create a new assignment of microstates to macrostates
new_assignment = np.zeros_like(msm.metastable_assignments)
for i in range(n_macrostates):
    new_assignment[msm.metastable_assignments == i] = mapping[i]

# Replace the old assignments with the new ones
# msm.metastable_assignments = new_assignment

# %%
new_assignment
# Out:
# array([2, 2, 0, 2, 1, 2, 3, 3, 0, 2, 2, 1, 2, 3, 2, 1, 3, 3, 2, 0, 0, 2,
#        2, 3, 3, 0, 2, 0, 1, 3, 1, 3, 2, 2, 2, 2, 0, 2, 2, 2, 3, 0, 1, 2,
#        2, 1, 3, 2, 1, 2])

# %%
metastable_traj = new_assignment[dtrajs_concatenated]

fig, ax = plt.subplots(figsize=(5, 4))
_, _, misc = pyemma.plots.plot_state_map(
    *tica_concatenated[:, :2].T, metastable_traj, ax=ax)
ax.set_xlabel('IC 1')
ax.set_ylabel('IC 2')
misc['cbar'].set_ticklabels([r'$\mathcal{S}_%d$' % (i + 1)
                             for i in range(nstates)])
fig.tight_layout()
# fig.savefig('pcca_update.png',dpi=400)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[295], line 1
# ----> 1 metastable_traj = new_assignment[dtrajs_concatenated]
#       3 fig, ax = plt.subplots(figsize=(5, 4))
#       4 _, _, misc = pyemma.plots.plot_state_map(
#       5     *tica_concatenated[:, :2].T, metastable_traj, ax=ax)
#
# IndexError: index 90 is out of bounds for axis 0 with size 50

# %%
# Compute MFPTs between all pairs of new PCCA+ states
mfpts = np.zeros((len(mapping), len(mapping)))
for i in range(len(mapping)):
    for j in range(len(mapping)):
        if i != j:
            mfpts[i, j] = msm.mfpt(
                msm.metastable_sets[new_assignment[i]],
                msm.metastable_sets[new_assignment[j]]
            )

from pandas import DataFrame
print('MFPT / ns:')
DataFrame(np.round(mfpt, decimals=2), index=range(1, nstates + 1), columns=range(1, nstates + 1))
# Out:
# MFPT / ns:
#           1         2         3         4
# 1      0.00   3052.39  14737.84  15530.90
# 2   8386.13      0.00  14785.08  15717.90
# 3  35704.46  28478.26      0.00   1306.85
# 4  36127.29  29109.63    922.48      0.00

# %%
mfpts
# Out:
# array([[    0.        ,     0.        , 35704.45588857,     0.        ],
#        [    0.        ,     0.        , 35704.45588857,     0.        ],
#        [14737.84140019, 14737.84140019,     0.        , 14737.84140019],
#        [    0.        ,     0.        , 35704.45588857,     0.        ]])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Run PCCA+ for different numbers of macrostates
n_macrostates = range(2, 11)  # for example
assignments = []

for n in n_macrostates:
    msm.pcca(n)
    assignments.append(msm.metastable_assignments)

# Create a plot for each number of macrostates
for i, n in enumerate(n_macrostates):
    plt.figure(i)
    plt.scatter(range(len(assignments[i])), assignments[i], c=assignments[i], cmap='viridis', alpha=0.6)
    plt.title(f'{n} macrostates')
    plt.xlabel('Microstate')
    plt.ylabel('Macrostate')
    plt.colorbar()

plt.show()

# %%
# Assume msm is your MarkovStateModel object
stationary_distribution = msm.stationary_distribution

# %%
# Transition matrix of your MSM
transition_matrix = msm.transition_matrix

# %%
np.shape(transition_matrix)
# Out:
# (100, 100)

# %%
P_AB = np.sum(transition_matrix[A][:, B])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[342], line 1
# ----> 1 P_AB = np.sum(transition_matrix[A][:, B])
#
# NameError: name 'A' is not defined

# %%
tlist=['../trajdat/dat2/rep1_tot.xtc','../trajdat/dat2/rep2_tot.xtc','../trajdat/dat2/rep3_tot.xtc',\
       '../trajdat/dat2/rep4.xtc','../trajdat/dat2/rep6_tot2.xtc','../trajdat/dat/1_tot.xtc','../trajdat/dat/3_tot.xtc',\
        '../trajdat/dat/5_tot.xtc','../trajdat/dat/9_tot.xtc']

# %%
pcca_samples = msm.sample_by_distributions(msm.metastable_distributions, 10)
torsions_source = pyemma.coordinates.source(tlist, top='../trajdat/dat/gro.gro')
pyemma.coordinates.save_trajs(
    torsions_source,
    pcca_samples,
    outfiles=['./in{}_tor.gro'.format(n + 1)
              for n in range(msm.n_metastable)])
# Out:
# Obtaining file info:   0%|                                | 0/9 [00:00<?, ?it/s]
# ['./in1_tor.gro', './in2_tor.gro', './in3_tor.gro', './in4_tor.gro']

# %%
msm.n_metastable
# Out:
# 4

# %%
pcca_samples = msm.sample_by_distributions(msm.metastable_distributions, 10)
torsions_source = pyemma.coordinates.source(tlist, top='../trajdat/dat/gro.gro')
pyemma.coordinates.save_trajs(
    torsions_source,
    pcca_samples,
    outfiles=['./in{}_tor.gro'.format(n + 1)
              for n in range(msm.n_metastable)])
# Out:
# Obtaining file info:   0%|                                | 0/9 [00:00<?, ?it/s]
# ['./in1_tor.gro', './in2_tor.gro', './in3_tor.gro']

# %%
msm.metastable_assignments
# Out:
# array([1, 1, 2, 1, 3, 1, 0, 0, 2, 1, 1, 3, 1, 0, 1, 3, 0, 0, 1, 2, 2, 1,
#        1, 0, 0, 2, 1, 2, 3, 0, 3, 0, 1, 1, 1, 1, 2, 1, 1, 1, 0, 2, 3, 1,
#        1, 3, 0, 1, 3, 1])

# %%
np.sum(msm.metastable_distributions)
# Out:
# 4.0

# %%
# Create a new metastable distributions array
new_distributions = np.zeros((len(mapping), msm.nstates))

# Compute the metastable distributions for each new metastable state
for i in range(len(mapping)):
    # Get the microstate indices that belong to this metastable state
    microstate_indices = np.where(np.array(new_assignment) == i)[0]
    
    # Assign the stationary probabilities of these microstates
    new_distributions[i, microstate_indices] = msm.stationary_distribution[microstate_indices]
    
    # Normalize the distribution so it sums to 1
    new_distributions[i] /= new_distributions[i].sum()

# new_distributions is now the metastable distributions for the new metastable states

# %%
pcca_samples = msm.sample_by_distributions(new_distributions, 10)
torsions_source = pyemma.coordinates.source(tlist, top='../trajdat/dat/gro.gro')
pyemma.coordinates.save_trajs(
    torsions_source,
    pcca_samples,
    outfiles=['./in{}_tor.gro'.format(n + 1)
              for n in range(msm.n_metastable)])
# Out:
# Obtaining file info:   0%|                                | 0/9 [00:00<?, ?it/s]
# ['./in1_tor.gro', './in2_tor.gro', './in3_tor.gro', './in4_tor.gro']

# %%
from itertools import product

mfpt = np.zeros((nstates, nstates))
for i, j in product(range(nstates), repeat=2):
    mfpt[i, j] = msm.mfpt(
        msm.metastable_sets[i],
        msm.metastable_sets[j])

from pandas import DataFrame
print('MFPT / ns:')
DataFrame(np.round(mfpt, decimals=2), index=range(1, nstates + 1), columns=range(1, nstates + 1))
# Out:
# MFPT / ns:
#            1         2        3        4
# 1       0.00   2176.53  4078.25  1648.34
# 2  205260.13      0.00  3830.17  1079.79
# 3  275415.15  71841.61     0.00   789.64
# 4  275850.78  72070.81  4223.50     0.00

# %%
new_assignment
# Out:
# array([2, 2, 0, 2, 1, 2, 3, 3, 0, 2, 2, 1, 2, 3, 2, 1, 3, 3, 2, 0, 0, 2,
#        2, 3, 3, 0, 2, 0, 1, 3, 1, 3, 2, 2, 2, 2, 0, 2, 2, 2, 3, 0, 1, 2,
#        2, 1, 3, 2, 1, 2])

# %%
msm.metastable_sets
# Out:
# [array([ 0, 10, 21, 38]),
#  array([ 3,  9, 14, 33, 34, 35, 43]),
#  array([ 7, 17, 23, 31]),
#  array([13, 16]),
#  array([ 6, 40, 46]),
#  array([ 5, 37]),
#  array([ 8, 20, 36]),
#  array([ 1,  4, 12, 15, 18, 22, 24, 25, 26, 27, 29, 30, 32, 39, 44, 47, 49]),
#  array([ 2, 19, 41]),
#  array([11, 28, 42, 45, 48])]

# %%
print('state\tπ\t\tG/kT')
for i, s in enumerate(msm.metastable_sets):
    p = msm.pi[s].sum()
    print('{}\t{:f}\t{:f}'.format(i + 1, p, -np.log(p)))
# Out:
# state	π		G/kT
# 1	0.025033	3.687553
# 2	0.046672	3.064608
# 3	0.024694	3.701202
# 4	0.020535	3.885602
# 5	0.024601	3.704963
# 6	0.058678	2.835690
# 7	0.140326	1.963789
# 8	0.258541	1.352703
# 9	0.159541	1.835453
# 10	0.241379	1.421388

# %%
print('state\tπ\t\tG/kT')
for i, s in enumerate(new_assignments):
    p = msm.pi[s].sum()
    print('{}\t{:f}\t{:f}'.format(i + 1, p, -np.log(p)))
# Out:
# state	π		G/kT
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[159], line 2
#       1 print('state\tπ\t\tG/kT')
# ----> 2 for i, s in enumerate(new_assignments):
#       3     p = msm.pi[s].sum()
#       4     print('{}\t{:f}\t{:f}'.format(i + 1, p, -np.log(p)))
#
# NameError: name 'new_assignments' is not defined

# %%
A = msm.metastable_sets[0]
B = np.concatenate(msm.metastable_sets[1:])
print('MFPT 1 -> other: ({:6.1f} ± {:5.1f}) ns'.format(
    msm.sample_mean('mfpt', A, B), msm.sample_std('mfpt', A, B)))
print('MFPT other -> 1: ({:.1f} ± {:5.1f}) ns'.format(
    msm.sample_mean('mfpt', B, A), msm.sample_std('mfpt', B, A)))
# Out:
# MFPT 1 -> other: ( 354.1 ±  54.0) ns
# MFPT other -> 1: (32630.1 ± 9760.7) ns

# %%
start, final = 0, 3
A = msm.metastable_sets[start]
B = msm.metastable_sets[final]
flux = pyemma.msm.tpt(msm, A, B)

cg, cgflux = flux.coarse_grain(msm.metastable_sets)

# %%
fig, ax = plt.subplots(figsize=(5, 4))

pyemma.plots.plot_contour(
    *tica_concatenated[:, :2].T,
    flux.committor[dtrajs_concatenated],
    cmap='brg',
    ax=ax,
    mask=True,
    cbar_label=r'committor $\mathcal{S}_%d \to \mathcal{S}_%d$' % (
        start + 1, final + 1))
fig.tight_layout()
plt.savefig('commitor_update.png',dpi=300)

# %%
msm
# Out:
# BayesianMSM(conf=0.95, connectivity='largest', core_set=None,
#       count_mode='effective', dt_traj='0.1 ns', lag=100,
#       milestoning_method='last_core', mincount_connectivity='1/n',
#       nsamples=100, nsteps=7, reversible=True, show_progress=True,
#       sparse=False, statdist_constraint=None)

# %%
# get the transition matrix
T = msm.transition_matrix

# print the transition matrix
# print(T)

# %%
print(T)
# Out:
# [[3.60060516e-01 1.13017718e-02 1.63011538e-02 ... 1.20722381e-01
#   5.70528534e-03 8.52577364e-02]
#  [8.72248841e-04 2.57545883e-01 0.00000000e+00 ... 4.19630415e-03
#   0.00000000e+00 0.00000000e+00]
#  [1.25473374e-04 0.00000000e+00 3.22533135e-01 ... 0.00000000e+00
#   0.00000000e+00 1.81274864e-01]
#  ...
#  [5.64365324e-02 2.54182486e-02 0.00000000e+00 ... 3.08367073e-01
#   2.01092298e-03 6.65309833e-04]
#  [1.54183157e-05 0.00000000e+00 0.00000000e+00 ... 1.16247191e-05
#   1.20314389e-01 0.00000000e+00]
#  [5.10284201e-04 0.00000000e+00 1.40955713e-01 ... 8.51784507e-06
#   0.00000000e+00 4.29338101e-01]]

# %%
msm.
# Out:
# BayesianMSM(conf=0.95, connectivity='largest', core_set=None,
#       count_mode='effective', dt_traj='0.1 ns', lag=100,
#       milestoning_method='last_core', mincount_connectivity='1/n',
#       nsamples=100, nsteps=7, reversible=True, show_progress=True,
#       sparse=False, statdist_constraint=None)

# %%
nstates = 4
msm.pcca(nstates)
for i, s in enumerate(msm.metastable_sets):
    print('π_{} = {:f}'.format(i + 1, msm.pi[s].sum()))
# Out:
# π_1 = 0.002752
# π_2 = 0.009335
# π_3 = 0.150822
# π_4 = 0.837091

# %%
metastable_traj = msm.metastable_assignments[dtrajs_concatenated]
highest_membership = msm.metastable_distributions.argmax(1)
coarse_state_centers = cluster.clustercenters[msm.active_set[highest_membership]]

# %%
mfpt = np.zeros((nstates, nstates))
for i in range(nstates):
    for j in range(nstates):
        mfpt[i, j] = msm.mfpt(
            msm.metastable_sets[i],
            msm.metastable_sets[j])

inverse_mfpt = np.zeros_like(mfpt)
nz = mfpt.nonzero()
inverse_mfpt[nz] = 1.0 / mfpt[nz]

# %%
fig, ax = plt.subplots(figsize=(10, 7))
_, _, misc = pyemma.plots.plot_state_map(
    *tica_concatenated[:, :2].T, metastable_traj, ax=ax, zorder=-1)
misc['cbar'].set_ticklabels(range(1, nstates + 1))  # set state numbers 1 ... nstates

pyemma.plots.plot_network(
    inverse_mfpt,
    pos=coarse_state_centers,
    figpadding=0,
    arrow_label_format='%.1f ns',
    arrow_labels=mfpt,
    size=12,
    show_frame=True,
    ax=ax)

# ax.set_xlabel('$\Phi$')
# ax.set_ylabel('$\Psi$')
ax.set_xlim(-2, 3)
ax.set_ylim(-2, 3)
fig.tight_layout()

# %%
A = msm.metastable_sets[0]
B = msm.metastable_sets[3]
flux = pyemma.msm.tpt(msm, A, B)

# %%
cg, cgflux = flux.coarse_grain(msm.metastable_sets)

# %%
fig, ax = plt.subplots(figsize=(10, 7))

pyemma.plots.plot_contour(
    *tica_concatenated[:, :2].T,
    flux.committor[dtrajs_concatenated],
    cmap='brg',
    ax=ax,
    mask=True,
    cbar_label=r'committor 1 $\to$ 4',
    alpha=0.8,
    zorder=-1);

pyemma.plots.plot_flux(
    cgflux,
    coarse_state_centers,
    cgflux.stationary_distribution,
    state_labels=['A','' ,'', 'B'],
    ax=ax,
    show_committor=False,
    figpadding=0,
    show_frame=True,
    arrow_label_format='%2.e / ns');

# ax.set_xlabel('$\Phi$')
# ax.set_ylabel('$\Psi$')
ax.set_xlim(-2,3)
ax.set_ylim(-2,3)
fig.tight_layout()
plt.savefig('committor.png',dpi=300)

# %%
paths, path_fluxes = cgflux.pathways(fraction=0.99)
print('percentage       \tpath')
print('-------------------------------------')
for i in range(len(paths)):
    print(np.round(path_fluxes[i] / np.sum(path_fluxes), 3),' \t', paths[i] + 1)
# Out:
# percentage       	path
# -------------------------------------
# 0.745  	 [1 2 4]
# 0.212  	 [1 2 3 4]
# 0.043  	 [1 3 4]

# %%
# Assume msm is your MarkovStateModel object
stationary_distribution = msm.stationary_distribution
# Transition matrix of your MSM
transition_matrix = msm.transition_matrix

# %%
A = [1]
B = [20]

# %%
P_AB = np.sum(transition_matrix[A][:, B])

# %%
P_AB
# Out:
# 0.017935465802923378

# %%
pi_A = stationary_distribution[A]

# %%
pi_A
# Out:
# array([0.00021679])

# %%
F_AB = np.sum(pi_A * P_AB)

# %%
F_AB
# Out:
# 3.888281282131186e-06

# %%
MFPT_AB = 1 / F_AB

# %%
MFPT_AB
# Out:
# 257183.03986791178

# %%
import numpy as np
from scipy.linalg import solve

def compute_mfpt(P, i, j):
    n = len(P)
    Q = np.copy(P)
    np.fill_diagonal(Q, 0)

    for k in range(n):
        Q[k, k] = -Q[k, :].sum()
    Q[j, :] = 0
    Q[j, j] = 1

    b = np.zeros(n)
    b[j] = 1

    x = solve(Q, b)

    return x[i]

# then use this function to calculate MFPT from state i to state j
# mfpt_ij = compute_mfpt(P, i, j)

# %%
mfpt_ij = compute_mfpt(P, i, j)
